# %% [markdown]
# # APEX STATS Dataset
# Prepared by Michelle Baca Reinke

# %% [markdown]
# ## Source Attribution
#
# Author: Data Copyright &copy; Nidula Elgiriyewithana, All Rights Reserved
#
# Title: Billionaires Statistics Dataset (2023)
#
# Source: The dataset was compiled from various sources, including Forbes and other financial publications
#
# License: Other
#
# Changes: Data have been adapted for APEX STATS by Michelle Baca Reinke; data has been condensed to a subset of the top 25 cases and selected variabes in the example version

# %% [markdown]
# ## Description of the Original Data
#
# This dataset contains statistics on the world's billionaires, including information about their businesses, industries, and personal details. It provides insights into the wealth distribution, business sectors, and demographics of billionaires worldwide.

# %% [markdown]
# ## Description of the Example
#
# Access this example using the file `example.csv`.
#
# The example file is a subset of the original data. Only the first 25 billionaires and the variables listed below are included.
#
# <br>
#
# The following variables are included:
#
# y: Ranking in terms of wealth (ordinal)
# x: Final net worth in U.S. dollars
# x1: Category or industry of business operation
# x2: Full name
# x3: Age
# x4: Country of residence
# x5: City of residence
# x6: Source of wealth
# x7: Industry associated with business interests
# x8: Associated organization name
# x9: Whether billionaire status is self-made (True/False; dichotimous)
# x10: Gender
#
# <br>
#
# Subsetting the data resulted in cases 26 through 2620 and the variables listed below being excluded from the example data file.
#
# - countryOfCitizenship: The country of citizenship of the billionaire.
# - status: "D" represents self-made billionaires (Founders/Entrepreneurs) and "U" indicates inherited or unearned wealth.
# - birthDate: The birthdate of the billionaire.
# - lastName: The last name of the billionaire.
# - firstName: The first name of the billionaire.
# - title: The title or honorific of the billionaire.
# - date: The date of data collection.
# - state: The state in which the billionaire resides.
# - residenceStateRegion: The region or state of residence of the billionaire.
# - birthYear: The birth year of the billionaire.
# - birthMonth: The birth month of the billionaire.
# - birthDay: The birth day of the billionaire.
# - cpi_country: Consumer Price Index (CPI) for the billionaire's country.
# - cpi_change_country: CPI change for the billionaire's country.
# - gdp_country: Gross Domestic Product (GDP) for the billionaire's country.
# - gross_tertiary_education_enrollment: Enrollment in tertiary education in the billionaire's country.
# - gross_primary_education_enrollment_country: Enrollment in primary education in the billionaire's country.
# - life_expectancy_country: Life expectancy in the billionaire's country.
# - tax_revenue_country_country: Tax revenue in the billionaire's country.
# - total_tax_rate_country: Total tax rate in the billionaire's country.
# - population_country: Population of the billionaire's country.
# - latitude_country: Latitude coordinate of the billionaire's country.
# - longitude_country: Longitude coordinate of the billionaire's country.

# %% [markdown]
# ## Discipline(s) Represented
#
# - Finance
# - Economics
# - Business

# %% [markdown]
# ## Dataset Preview

# %%
#@title Setup Example Data: Billionaires

# Import library
import pandas as pd

# Read data file: World University Rankings 2023
data = pd.read_csv('https://raw.githubusercontent.com/livid2nite/APEX/main/billionaires/example.csv')

# Preview data
data.head()
# Out:
#    y       x                     x1                        x2  x3  \
# 0  1  211000       Fashion & Retail  Bernard Arnault & family  74
# 1  2  180000             Automotive                 Elon Musk  51
# 2  3  114000             Technology                Jeff Bezos  59
# 3  4  107000             Technology             Larry Ellison  78
# 4  5  106000  Finance & Investments            Warren Buffett  92
#
#               x4      x5                  x6                     x7     x8 x9
# 0         France   Paris                LVMH       Fashion & Retail  False  M
# 1  United States  Austin       Tesla, SpaceX             Automotive   True  M
# 2  United States  Medina              Amazon             Technology   True  M
# 3  United States   Lanai              Oracle             Technology   True  M
# 4  United States   Omaha  Berkshire Hathaway  Finance & Investments   True  M

# %% [markdown]
# ## Exploratory Analyses (untested)
#
# - Explore the distribution of billionaires' wealth across different industries or countries
# - Invesitgate demographic characteristics (age, gender)
# - Analyze the proportion of self-made billionaires and those who inherited their wealth
